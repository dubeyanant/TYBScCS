# %%
#Q1
#import the library
import pandas as pd
#create an empty data frame with columns names
df = pd.DataFrame(columns =['Name','Age','Percentage'])
#Add records
df.loc[0] = ['Izuku',21,80]
df.loc[1] = ['Kurosaki',24,70]
df.loc[2] = ['Sasuke',31,67]
df.loc[3] = ['Shoto',22,78]
df.loc[4] = ['Reigen',38,98]
df.loc[5] = ['Violet',26,76]
df.loc[6] = ['Bakugo',22,74]
df.loc[7] = ['Tobio',23,69]
df.loc[8] = ['Koyomi',23,79]
df.loc[9] = ['Shigeo',25,88]
df
# Out:
#        Name  Age  Percentage
# 0     Izuku   21          80
# 1  Kurosaki   24          70
# 2    Sasuke   31          67
# 3     Shoto   22          78
# 4    Reigen   38          98
# 5    Violet   26          76
# 6    Bakugo   22          74
# 7     Tobio   23          69
# 8    Koyomi   23          79
# 9    Shigeo   25          88

# %%
#Q2 print shape
df.shape
# Out:
# (10, 3)

# %%
#Q2 print row and columns,data-types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Percentage  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
#Q3 print basic statistical details of the data
df.describe()
# Out:
#              Age  Percentage
# count  10.000000   10.000000
# mean   25.500000   77.900000
# std     5.233439    9.374315
# min    21.000000   67.000000
# 25%    22.250000   71.000000
# 50%    23.500000   77.000000
# 75%    25.750000   79.750000
# max    38.000000   98.000000

# %%
#Q4 add 5 rows with duplicate values and missing values.
df.loc[10] = ['Bakugo',None,74]
df.loc[11] = ['Onizuka',26,76]
df.loc[12] = ['Sasuke',None,None]
df.loc[13] = ['Shigeo',24,70]
df.loc[14] = ['Kaguya',None,None]
#Insert empty column
df["remarks"] = None
df
# Out:
#         Name   Age Percentage remarks
# 0      Izuku    21         80    None
# 1   Kurosaki    24         70    None
# 2     Sasuke    31         67    None
# 3      Shoto    22         78    None
# 4     Reigen    38         98    None
# 5     Violet    26         76    None
# 6     Bakugo    22         74    None
# 7      Tobio    23         69    None
# 8     Koyomi    23         79    None
# 9     Shigeo    25         88    None
# 10    Bakugo  None         74    None
# 11   Onizuka    26         76    None
# 12    Sasuke  None       None    None
# 13    Shigeo    24         70    None
# 14    Kaguya  None       None    None

# %%
#Q5 to get no.of observations,missing values and duplicate values
df.isnull()
# Out:
#      Name    Age  Percentage  remarks
# 0   False  False       False     True
# 1   False  False       False     True
# 2   False  False       False     True
# 3   False  False       False     True
# 4   False  False       False     True
# 5   False  False       False     True
# 6   False  False       False     True
# 7   False  False       False     True
# 8   False  False       False     True
# 9   False  False       False     True
# 10  False   True       False     True
# 11  False  False       False     True
# 12  False   True        True     True
# 13  False  False       False     True
# 14  False   True        True     True

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
#Q6 to drop 'remarks' column from the dataframe. also drop all null and empty values. print the modified data.
df.drop(columns='remarks',axis=1,inplace=True)
df
# Out:
#         Name   Age Percentage
# 0      Izuku    21         80
# 1   Kurosaki    24         70
# 2     Sasuke    31         67
# 3      Shoto    22         78
# 4     Reigen    38         98
# 5     Violet    26         76
# 6     Bakugo    22         74
# 7      Tobio    23         69
# 8     Koyomi    23         79
# 9     Shigeo    25         88
# 10    Bakugo  None         74
# 11   Onizuka    26         76
# 12    Sasuke  None       None
# 13    Shigeo    24         70
# 14    Kaguya  None       None

# %%
#drop all null and empty values.
df.dropna()
# Out:
#         Name Age Percentage
# 0      Izuku  21         80
# 1   Kurosaki  24         70
# 2     Sasuke  31         67
# 3      Shoto  22         78
# 4     Reigen  38         98
# 5     Violet  26         76
# 6     Bakugo  22         74
# 7      Tobio  23         69
# 8     Koyomi  23         79
# 9     Shigeo  25         88
# 11   Onizuka  26         76
# 13    Shigeo  24         70

# %%
#Q7 To generate line plot of name vs percentage
import matplotlib.pyplot as plt
df.plot(x='Name',y='Percentage')
plt.title('cmparison between name and percentage')
plt.show()

# %%
#Q8 To generate a scatter plot of name vs percentage
import matplotlib.pyplot as plt
plt.scatter(df['Name'],df['Percentage'])
plt.show()
