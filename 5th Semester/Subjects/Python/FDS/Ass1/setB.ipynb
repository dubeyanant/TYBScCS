# %%
import io
import pandas as pd
df = pd.read_csv("HeightWeight.csv")
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
#Q1
df.head(10)
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# 5      6        68.69784        123.3024
# 6      7        69.80204        141.4947
# 7      8        70.01472        136.4623
# 8      9        67.90265        112.3723
# 9     10        66.78236        120.6672

# %%
df.tail(10)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24990  24991        69.97767        125.3672
# 24991  24992        71.91656        128.2840
# 24992  24993        70.96218        146.1936
# 24993  24994        66.19462        118.7974
# 24994  24995        67.21126        127.6603
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df.sample(20)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 16781  16782        67.78870        117.1692
# 18035  18036        70.04402        139.6768
# 15173  15174        65.70932        124.1531
# 12730  12731        68.61440        130.4149
# 13453  13454        67.81842        107.4346
# 21706  21707        68.46424        133.7977
# 12722  12723        69.07966        147.9838
# 22841  22842        68.89049        125.4419
# 20784  20785        67.98409        122.7703
# 18041  18042        68.09486        128.0449
# 4046    4047        68.91770        148.7167
# 24576  24577        67.87733        116.6834
# 13678  13679        69.41193        124.4338
# 8625    8626        70.22831        144.6741
# 23775  23776        65.50539        143.9237
# 23767  23768        68.95166        129.3768
# 5659    5660        67.72994        134.9223
# 12876  12877        67.92363        126.3504
# 5122    5123        69.33663        124.8379
# 8802    8803        71.14142        130.5105

# %%
#Q2
df.shape
# Out:
# (25000, 3)

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
#Q3
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
#Q4
df.isnull()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
#Q5
df["BMI"] = df["Weight(Pounds)"] / (df["Height(Inches)"]**2)
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)       BMI
# 0          1        65.78331        112.9925  0.026111
# 1          2        71.51521        136.4873  0.026687
# 2          3        69.39874        153.0269  0.031773
# 3          4        68.21660        142.3354  0.030587
# 4          5        67.78781        144.2971  0.031402
# ...      ...             ...             ...       ...
# 24995  24996        69.50215        118.0312  0.024434
# 24996  24997        64.54826        120.1932  0.028848
# 24997  24998        64.69855        118.2655  0.028253
# 24998  24999        67.52918        132.2682  0.029005
# 24999  25000        68.87761        124.8742  0.026322
#
# [25000 rows x 4 columns]

# %%
0#Q6
max(df["BMI"])
# Out:
# 0.03701443692089851

# %%
min(df["BMI"])
# Out:
# 0.018591137267932455

# %%
#Q7
import matplotlib.pyplot as plt
plt.scatter(df['Height(Inches)'], df['Weight(Pounds)'])
plt.show()
