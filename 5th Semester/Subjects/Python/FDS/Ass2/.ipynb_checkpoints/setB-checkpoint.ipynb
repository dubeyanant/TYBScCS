# %%
import io
import pandas as pd
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.sample()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83  84            6.0           2.7            5.1           1.6
#
#             Species
# 83  Iris-versicolor

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
#Q2
print(df.mean())
print(df['SepalLengthCm'].value_counts())
print(df['SepalWidthCm'].value_counts())
print(df['PetalLengthCm'].value_counts())
print(df['PetalWidthCm'].value_counts())
print(df['Species'].value_counts())
print('\n')
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: SepalWidthCm, dtype: int64
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# ...

# %%
#Q3
print('mean of sepal length ',df['SepalLengthCm'].mean())
print('median of sepal length ',df['SepalLengthCm'].median())
print('\n')
print('mean of sepal width',df['SepalWidthCm'].mean())
print('median of sepal width',df['SepalWidthCm'].median())
print('\n')
print('mean of petal length ',df['PetalLengthCm'].mean())
print('median of petal length ',df['PetalLengthCm'].median())
print('\n')
print('mean of petal width ',df['PetalWidthCm'].mean())
print('median of petal width ',df['PetalWidthCm'].median())
print('\n')
# Out:
# mean of sepal length  5.843333333333334
# median of sepal length  5.8
#
#
# mean of sepal width 3.0540000000000003
# median of sepal width 3.0
#
#
# mean of petal length  3.758666666666666
# median of petal length  4.35
#
#
# mean of petal width  1.1986666666666668
# median of petal width  1.3
